# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRESTA-YARABOLU/-LGMVIP--DataScience/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LetsGrowMore - August 2022
# Shresta Yarabolu - Data Science Intern
# Task 1.4 - Image to Pencil Sketch with python

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b397eb37-11df-4d66-bdff-da68753a6fe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b397eb37-11df-4d66-bdff-da68753a6fe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flower.jpg to flower.jpg

# %%
image=cv2.imread('flower.jpg')
original_image =cv2.resize(image, (500, 500))
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FC1939E3BD0>

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FC1939E3610>

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FC193A77650>

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FC1939E3650>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)
cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FC1939E8990>

# %%
cv2_imshow(original_image)
cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FC1939E3E50>
# <PIL.Image.Image image mode=L size=500x500 at 0x7FC1939E3D50>
